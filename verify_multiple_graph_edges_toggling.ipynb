# %% [markdown]
# ### Overview
#
# This code explores whether there is a correlation between toggling of multiple edges (effectively, subgraphs) and spectral/controllability properties. The edges are toggled in the order based on a specified score.

# %%
######################### Uninterseting edge score 'Wc_spec_dist' for cumulative flips

# from modules.single_graph_edge_expt import graph_edge_toggling_expt_using_given_graphs_and_scoring_choice
# from modules.graphs import get_graph
# import numpy as np
# # %config InlineBackend.figure_format = 'svg'

# graph_choices_1 = [{'type': 'connected_ER', 'n': 20, 'p': 0.5},
#                  {'type': 'connected_RG', 'n': 20, 'r': 0.25},
#                  {'type':           'BA', 'n': 20, 'm': 5, 'init': {'type': 'complete', 'n': 5}}]
# n_graphs = 100
# graphs_1 = [[get_graph(graph_choice=choice) for _ in range(n_graphs)] for choice in graph_choices_1]
# matrix_choices = ['neg_laplacian']
# # matrix_choices = ['adjacency', 'neg_laplacian', 'normalized_laplacian', 'neg_normalized_laplacian',
# #                   'signless_laplacian', 'neg_signless_laplacian', 'distance_normalized_laplacian', 'neg_distance_normalized_laplacian']
# # input_choices = ['zfs_transf']
# input_choices = ['all_ones', 'identity', 'zfs', 'zfs_transf', 'zfs_new']

# graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_1, graphs_1, matrix_choices, input_choices,
#         edge_score_choices=['Wc_spec_dist'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

# %%
import sys
import os
from os.path import dirname, abspath
sys.path.insert(0, os.path.join(abspath(os.getcwd()), 'modules'))

from single_graph_edge_expt import graph_edge_toggling_expt_using_given_graphs_and_scoring_choice
from graphs import get_graph
import numpy as np
# %config InlineBackend.figure_format = 'svg'

matrix_choices = ['neg_laplacian']
# matrix_choices = ['adjacency', 'neg_laplacian', 'normalized_laplacian', 'neg_normalized_laplacian',
#                   'signless_laplacian', 'neg_signless_laplacian', 'distance_normalized_laplacian', 'neg_distance_normalized_laplacian']
# input_choices = ['zfs_transf']
input_choices = ['all_ones', 'identity', 'zfs', 'zfs_transf', 'zfs_new']

n_graphs = 100

graph_choice_sets = [[{'type': 'connected_ER', 'n': 20, 'p': 0.3},
                      {'type': 'connected_RG', 'n': 20, 'r': 0.25},
                      {'type':           'BA', 'n': 20, 'm': 3, 'init': {'type': 'complete', 'n': 5}}],
                     [{'type': 'connected_ER', 'n': 20, 'p': 0.5},
                      {'type': 'connected_RG', 'n': 20, 'r': 0.5},
                      {'type':           'BA', 'n': 20, 'm': 5, 'init': {'type': 'complete', 'n': 5}}],
                     [{'type': 'connected_ER', 'n': 20, 'p': 0.7},
                      {'type': 'connected_RG', 'n': 20, 'r': 0.75},
                      {'type':           'BA', 'n': 20, 'm': 8, 'init': {'type': 'complete', 'n': 8}}]]
list_of_graph_lists = [[[get_graph(graph_choice=choice) for _ in range(n_graphs)] for choice in graph_choice_set] for graph_choice_set in graph_choice_sets]

# %%
for graph_choices_set, graphs in zip(graph_choice_sets, list_of_graph_lists):
    graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['adjacency', 'neg_laplacian'],
        input_choices=input_choices,
        edge_score_choices=['random'], plot_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
        sort_by_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
        multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

    # # no significant correlation between sys_mat_spec_dist and random edge score
    # graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_1, graphs_1, matrix_choices, input_choices,
    #         edge_score_choices=['random'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

    graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['neg_laplacian', 'adjacency'], input_choices=input_choices,
        edge_score_choices=['ETEC'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv',
        other_pairs_of_quantities_to_plot=[{'y1': 'ETEC', 'y2': 'Wc_spec_dist'}, {'y1': 'sys_mat_spec_dist', 'y2': 'Wc_spec_dist'}])#, plot_all_ignoring_low_corr=True)

    graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['neg_laplacian'], input_choices=['identity'],
        edge_score_choices=['ETEC_sys_mat'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv',
        other_pairs_of_quantities_to_plot=[{'y1': 'ETEC_sys_mat', 'y2': 'Wc_spec_dist'}, {'y1': 'sys_mat_spec_dist', 'y2': 'Wc_spec_dist
# Processing graphs: 100%|██████████| 100/100 [07:14<00:00,  4.35s/it]
# Processing graphs: 100%|██████████| 100/100 [05:41<00:00,  3.42s/it]
# Processing graphs: 100%|██████████| 100/100 [05:41<00:00,  3.42s/it]
# Processing graphs: 100%|██████████| 100/100 [10:33<00:00,  6.34s/it]
# Processing graphs: 100%|██████████| 100/100 [10:35<00:00,  6.36s/it]
# Processing graphs: 100%|██████████| 100/100 [11:15<00:00,  6.75s/it]
# Processing graphs: 100%|██████████| 100/100 [05:44<00:00,  3.45s/it]
# Processing graphs: 100%|██████████| 100/100 [03:46<00:00,  2.27s/it]
# Processing graphs: 100%|██████████| 100/100 [02:02<00:00,  1.22s/it]
# Processing graphs: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# Processing graphs: 100%|██████████| 100/100 [01:44<00:00,  1.04s/it]
# Processing graphs: 100%|██████████| 100/100 [01:03<00:00,  1.57it/s]
# Processing graphs: 100%|██████████| 100/100 [01:02<00:00,  1.59it/s]
# Processing graphs: 100%|██████████| 100/100 [01:06<00:00,  1.51it/s]
# Processing graphs: 100%|██████████| 100/100 [01:16<00:00,  1.30it/s]
# Processing graphs: 100%|██████████| 100/100 [01:09<00:00,  1.44it/s]
# Processing graphs: 100%|██████████| 100/100 [02:48<00:00,  1.69s/it]
# Processing graphs: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# Processing graphs: 100%|██████████| 100/100 [02:24<00:00,  1.44s/it]
# Processing graphs: 100%|██████████| 100/100 [02:38<00:00,  1.58s/it]
# Processing graphs: 100%|██████████| 100/100 [02:10<00:00,  1.31s/it]

# %%
# test random score for comparison against ETEC
for graph_choices_set, graphs in zip(graph_choice_sets, list_of_graph_lists):
    graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['adjacency', 'neg_laplacian'],
        input_choices=input_choices, edge_score_choices=['random'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv',
        other_pairs_of_quantities_to_plot=[{'y1': 'random', 'y2': 'Wc_spec_dist'}, {'y1': 'sys_mat_spec_dist', 'y2': 'Wc_spec_dist'}])
# Out:
# Processing graphs: 100%|██████████| 100/100 [01:39<00:00,  1.00it/s]
# Processing graphs: 100%|██████████| 100/100 [04:48<00:00,  2.89s/it]
# Processing graphs: 100%|██████████| 100/100 [04:49<00:00,  2.89s/it]
# Processing graphs: 100%|██████████| 100/100 [05:00<00:00,  3.00s/it]
# Processing graphs: 100%|██████████| 100/100 [04:56<00:00,  2.97s/it]
# Processing graphs: 100%|██████████| 100/100 [04:56<00:00,  2.96s/it]
# Processing graphs: 100%|██████████| 100/100 [04:53<00:00,  2.94s/it]
# Processing graphs: 100%|██████████| 100/100 [04:08<00:00,  2.48s/it]
# Processing graphs: 100%|██████████| 100/100 [01:20<00:00,  1.23it/s]
# Processing graphs: 100%|██████████| 100/100 [01:37<00:00,  1.03it/s]
# Processing graphs: 100%|██████████| 100/100 [01:19<00:00,  1.25it/s]
# Processing graphs: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Processing graphs: 100%|██████████| 100/100 [02:06<00:00,  1.26s/it]
# Processing graphs: 100%|██████████| 100/100 [02:35<00:00,  1.55s/it]
# Processing graphs: 100%|██████████| 100/100 [02:08<00:00,  1.28s/it]
# Processing graphs: 100%|██████████| 100/100 [02:14<00:00,  1.34s/it]
# Processing graphs: 100%|██████████| 100/100 [01:27<00:00,  1.15it/s]
# Processing graphs: 100%|██████████| 100/100 [01:35<00:00,  1.05it/s]
# Processing graphs: 100%|██████████| 100/100 [01:42<00:00,  1.02s/it]
# Processing graphs: 100%|██████████| 100/100 [01:35<00:00,  1.04it/s]
# Processing graphs: 100%|██████████| 100/100 [01:35<00:00,  1.05it/s]
# Processing graphs: 100%|██████████| 100/100 [01:26<00:00,  1.15it/s]
# Processing graphs: 100%|██████████| 100/100 [01:36<00:00,  1.04it/s]
# Processing graphs: 100%|██████████| 100/100 [13:13<00:00,  7.94s/it]
# Processing graphs: 100%|██████████| 100/100 [01:26<00:00,  1.16it/s]
# Processing graphs: 100%|██████████| 100/100 [01:59<00:00,  1.20s/it]
# Processing graphs: 100%|██████████| 100/100 [01:36<00:00,  1.04it/s]
# Processing graphs: 100%|██████████| 100/100 [00:52<00:00,  1.91it/s]
# Processing graphs: 100%|██████████| 100/100 [01:00<00:00,  1.64it/s]
# Processing graphs: 100%|██████████| 100/100 [00:57<00:00,  1.73it/s]
# Processing graphs: 100%|██████████| 100/100 [00:55<00:00,  1.79it/s]
# Processing graphs: 100%|██████████| 100/100 [01:05<00:00,  1.52it/s]
# Processing graphs: 100%|██████████| 100/100 [00:58<00:00,  1.70it/s]
# Processing graphs: 100%|██████████| 100/100 [00:56<00:00,  1.78it/s]
# Processing graphs: 100%|██████████| 100/100 [01:04<00:00,  1.54it/s]
# Processing graphs: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# Processing graphs: 100%|██████████| 100/100 [00:54<00:00,  1.83it/s]
# Processing graphs: 100%|██████████| 100/100 [01:05<00:00,  1.52it/s]
# Processing graphs: 100%|██████████| 100/100 [01:02<00:00,  1.59it/s]
# Processing graphs: 100%|██████████| 100/100 [01:38<00:00,  1.02it/s]
# Processing graphs: 100%|██████████| 100/100 [01:47<00:00,  1.08s/it]
# Processing graphs: 100%|██████████| 100/100 [01:45<00:00,  1.06s/it]
# Processing graphs: 100%|██████████| 100/100 [01:04<00:00,  1.55it/s]
# Processing graphs: 100%|██████████| 100/100 [00:55<00:00,  1.80it/s]
# Processing graphs: 100%|██████████| 100/100 [00:53<00:00,  1.87it/s]
# Processing graphs: 100%|██████████| 100/100 [01:06<00:00,  1.49it/s]
# Processing graphs: 100%|██████████| 100/100 [01:02<00:00,  1.60it/s]
# Processing graphs: 100%|██████████| 100/100 [00:55<00:00,  1.80it/s]
# Processing graphs: 100%|██████████| 100/100 [00:54<00:00,  1.82it/s]
# Processing graphs: 100%|██████████| 100/100 [00:58<00:00,  1.72it/s]
# Processing graphs: 100%|██████████| 100/100 [01:04<00:00,  1.54it/s]
# Processing graphs: 100%|██████████| 100/100 [01:49<00:00,  1.09s/it]
# Processing graphs: 100%|██████████| 100/100 [01:48<00:00,  1.08s/it]
# Processing graphs: 100%|██████████| 100/100 [01:38<00:00,  1.01it/s]
# Processing graphs: 100%|██████████| 100/100 [01:10<00:00,  1.41it/s]
# Processing graphs: 100%|██████████| 100/100 [01:04<00:00,  1.56it/s]
# Processing graphs: 100%|██████████| 100/100 [01:07<00:00,  1.48it/s]
# Processing graphs: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# Processing graphs: 100%|██████████| 100/100 [01:04<00:00,  1.54it/s]
# Processing graphs: 100%|██████████| 100/100 [01:12<00:00,  1.38it/s]
# Processing graphs: 100%|██████████| 100/100 [01:07<00:00,  1.47it/s]
# Processing graphs: 100%|██████████| 100/100 [01:05<00:00,  1.53it/s]
# Processing graphs: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# Processing graphs: 100%|██████████| 100/100 [01:02<00:00,  1.61it/s]
# Processing graphs: 100%|██████████| 100/100 [01:19<00:00,  1.25it/s]
# Processing graphs: 100%|██████████| 100/100 [01:17<00:00,  1.30it/s]
# Processing graphs: 100%|██████████| 100/100 [01:49<00:00,  1.10s/it]
# Processing graphs: 100%|██████████| 100/100 [01:58<00:00,  1.18s/it]
# Processing graphs: 100%|██████████| 100/100 [01:51<00:00,  1.11s/it]
# Processing graphs: 100%|██████████| 100/100 [01:16<00:00,  1.30it/s]
# Processing graphs: 100%|██████████| 100/100 [01:10<00:00,  1.42it/s]
# Processing graphs: 100%|██████████| 100/100 [01:26<00:00,  1.16it/s]
# Processing graphs: 100%|██████████| 100/100 [01:03<00:00,  1.58it/s]
# Processing graphs: 100%|██████████| 100/100 [01:08<00:00,  1.46it/s]
# Processing graphs: 100%|██████████| 100/100 [01:02<00:00,  1.60it/s]
# Processing graphs: 100%|██████████| 100/100 [01:21<00:00,  1.23it/s]
# Processing graphs: 100%|██████████| 100/100 [01:14<00:00,  1.35it/s]
# Processing graphs: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# Processing graphs: 100%|██████████| 100/100 [01:54<00:00,  1.14s/it]
# Processing graphs: 100%|██████████| 100/100 [02:02<00:00,  1.23s/it]
# Processing graphs: 100%|██████████| 100/100 [01:54<00:00,  1.15s/it]
