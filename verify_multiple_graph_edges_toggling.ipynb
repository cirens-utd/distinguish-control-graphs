# %% [markdown]
# ### Overview
#
# This code explores whether there is a correlation between toggling of multiple edges (effectively, subgraphs) and spectral/controllability properties. The edges are toggled in the order based on a specified score.

# %%
######################### Uninterseting edge score 'Wc_spec_dist' for cumulative flips

# from modules.single_graph_edge_expt import graph_edge_toggling_expt_using_given_graphs_and_scoring_choice
# from modules.graphs import get_graph
# import numpy as np
# # %config InlineBackend.figure_format = 'svg'

# graph_choices_1 = [{'type': 'connected_ER', 'n': 20, 'p': 0.5},
#                  {'type': 'connected_RG', 'n': 20, 'r': 0.25},
#                  {'type':           'BA', 'n': 20, 'm': 5, 'init': {'type': 'complete', 'n': 5}}]
# n_graphs = 100
# graphs_1 = [[get_graph(graph_choice=choice) for _ in range(n_graphs)] for choice in graph_choices_1]
# matrix_choices = ['neg_laplacian']
# # matrix_choices = ['adjacency', 'neg_laplacian', 'normalized_laplacian', 'neg_normalized_laplacian',
# #                   'signless_laplacian', 'neg_signless_laplacian', 'distance_normalized_laplacian', 'neg_distance_normalized_laplacian']
# # input_choices = ['zfs_transf']
# input_choices = ['all_ones', 'identity', 'zfs', 'zfs_transf', 'zfs_new']

# graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_1, graphs_1, matrix_choices, input_choices,
#         edge_score_choices=['Wc_spec_dist'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

# %%
import sys
import os
from os.path import dirname, abspath
sys.path.insert(0, os.path.join(abspath(os.getcwd()), 'modules'))

from single_graph_edge_expt import graph_edge_toggling_expt_using_given_graphs_and_scoring_choice
from graphs import get_graph
import numpy as np
# %config InlineBackend.figure_format = 'svg'

matrix_choices = ['neg_laplacian']
# matrix_choices = ['adjacency', 'neg_laplacian', 'normalized_laplacian', 'neg_normalized_laplacian',
#                   'signless_laplacian', 'neg_signless_laplacian', 'distance_normalized_laplacian', 'neg_distance_normalized_laplacian']
# input_choices = ['zfs_transf']
input_choices = ['all_ones', 'identity', 'zfs', 'zfs_transf', 'zfs_new']

n_graphs = 100

graph_choice_sets = [[{'type': 'connected_ER', 'n': 20, 'p': 0.3},
                      {'type': 'connected_RG', 'n': 20, 'r': 0.25},
                      {'type':           'BA', 'n': 20, 'm': 3, 'init': {'type': 'complete', 'n': 5}}],
                     [{'type': 'connected_ER', 'n': 20, 'p': 0.5},
                      {'type': 'connected_RG', 'n': 20, 'r': 0.5},
                      {'type':           'BA', 'n': 20, 'm': 5, 'init': {'type': 'complete', 'n': 5}}],
                     [{'type': 'connected_ER', 'n': 20, 'p': 0.7},
                      {'type': 'connected_RG', 'n': 20, 'r': 0.75},
                      {'type':           'BA', 'n': 20, 'm': 8, 'init': {'type': 'complete', 'n': 8}}]]
list_of_graph_lists = [[[get_graph(graph_choice=choice) for _ in range(n_graphs)] for choice in graph_choice_set] for graph_choice_set in graph_choice_sets]

# %%
for graph_choices_set, graphs in zip(graph_choice_sets, list_of_graph_lists):
    # graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['adjacency', 'neg_laplacian'],
    #     input_choices=input_choices,
    #     edge_score_choices=['random'], plot_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
    #     sort_by_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
    #     multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

    # # no significant correlation between sys_mat_spec_dist and random edge score
    # graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_1, graphs_1, matrix_choices, input_choices,
    #         edge_score_choices=['random'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

    graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['neg_laplacian', 'adjacency'], input_choices=input_choices,
        edge_score_choices=['ETEC'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv',
        other_pairs_of_quantities_to_plot=[
            # {'y1': 'ETEC', 'y2': 'Wc_spec_dist'},
            {'y1': 'sys_mat_spec_dist', 'y2': 'Wc_spec_dist'},
            {'y1': 'sys_mat_spec_dist', 'y2': 'density'},
            {'y1': 'Wc_spec_dist', 'y2': 'density'}])#, plot_all_ignoring_low_corr=True)

    graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['neg_laplacian'], input_choices=['identity'],
        edge_score_choices=['ETEC_sys_mat'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv',
        other_pairs_of_quantities_to_plot=[
            # {'y1': 'ETEC', 'y2': 'Wc_spec_dist'},
            {'y1': 'sys_mat_spec_dist', 'y2': 'Wc_spec_dist'},
            {'y1': 'sys_mat_spec_dist', 'y2': 'density'},
            {'y1': 'Wc_spec_dist', 'y2': 'density'}])#, plot_all_ignoring_low_corr=True)
# Out:
# Processing graphs: 100%|██████████| 100/100 [01:05<00:00,  1.53it/s]
# Processing graphs: 100%|██████████| 100/100 [01:45<00:00,  1.06s/it]
# Processing graphs: 100%|██████████| 100/100 [01:34<00:00,  1.06it/s]
# Processing graphs: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# Processing graphs: 100%|██████████| 100/100 [01:18<00:00,  1.27it/s]
# Processing graphs: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# Processing graphs: 100%|██████████| 100/100 [01:08<00:00,  1.46it/s]
# Processing graphs: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Processing graphs: 100%|██████████| 100/100 [02:39<00:00,  1.59s/it]
# Processing graphs: 100%|██████████| 100/100 [05:34<00:00,  3.34s/it]
# Processing graphs: 100%|██████████| 100/100 [02:53<00:00,  1.74s/it]
# Processing graphs: 100%|██████████| 100/100 [02:34<00:00,  1.54s/it]
# Processing graphs: 100%|██████████| 100/100 [01:58<00:00,  1.18s/it]
# Processing graphs: 100%|██████████| 100/100 [01:11<00:00,  1.40it/s]
# Processing graphs: 100%|██████████| 100/100 [01:47<00:00,  1.07s/it]
# Processing graphs: 100%|██████████| 100/100 [01:14<00:00,  1.34it/s]
# Processing graphs: 100%|██████████| 100/100 [01:10<00:00,  1.41it/s]
# Processing graphs: 100%|██████████| 100/100 [00:58<00:00,  1.71it/s]
# Processing graphs: 100%|██████████| 100/100 [01:05<00:00,  1.53it/s]
# Processing graphs: 100%|██████████| 100/100 [01:10<00:00,  1.41it/s]
# Processing graphs: 100%|██████████| 100/100 [01:05<00:00,  1.53it/s]
# Processing graphs: 100%|██████████| 100/100 [01:06<00:00,  1.50it/s]
# Processing graphs: 100%|██████████| 100/100 [01:10<00:00,  1.43it/s]
# Processing graphs: 100%|██████████| 100/100 [01:06<00:00,  1.51it/s]
# Processing graphs: 100%|██████████| 100/100 [01:55<00:00,  1.15s/it]
# Processing graphs: 100%|██████████| 100/100 [8:18:32<00:00, 299.12s/it]
# Processing graphs: 100%|██████████| 100/100 [11:06<00:00,  6.67s/it]
# Processing graphs: 100%|██████████| 100/100 [06:40<00:00,  4.00s/it]
# Processing graphs: 100%|██████████| 100/100 [07:25<00:00,  4.46s/it]
# Processing graphs: 100%|██████████| 100/100 [06:56<00:00,  4.16s/it]

# %%
# test random score for comparison against ETEC
for graph_choices_set, graphs in zip(graph_choice_sets, list_of_graph_lists):
    graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['adjacency', 'neg_laplacian'],
        input_choices=input_choices, edge_score_choices=['random'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv',
        other_pairs_of_quantities_to_plot=[
            # {'y1': 'random', 'y2': 'Wc_spec_dist'},
            {'y1': 'sys_mat_spec_dist', 'y2': 'Wc_spec_dist'},
            {'y1': 'sys_mat_spec_dist', 'y2': 'density'},
            {'y1': 'Wc_spec_dist', 'y2': 'density'}])
# Out:
# Processing graphs: 100%|██████████| 100/100 [00:53<00:00,  1.88it/s]
# Processing graphs: 100%|██████████| 100/100 [03:00<00:00,  1.80s/it]
# Processing graphs: 100%|██████████| 100/100 [04:43<00:00,  2.83s/it]
# Processing graphs: 100%|██████████| 100/100 [04:49<00:00,  2.89s/it]
# Processing graphs: 100%|██████████| 100/100 [04:57<00:00,  2.98s/it]
 100%|██████████| 100/100 [01:53<00:00,  1.14s/it]
# Processing graphs: 100%|██████████| 100/100 [01:53<00:00,  1.13s/it]
# Processing graphs: 100%|██████████| 100/100 [02:13<00:00,  1.34s/it]
# Processing graphs: 100%|██████████| 100/100 [03:25<00:00,  2.06s/it]
# Processing graphs: 100%|██████████| 100/100 [02:03<00:00,  1.23s/it]
# Processing graphs: 100%|██████████| 100/100 [03:33<00:00,  2.13s/it]
# Processing graphs: 100%|██████████| 100/100 [02:57<00:00,  1.78s/it]
# Processing graphs: 100%|██████████| 100/100 [02:48<00:00,  1.68s/it]
# Processing graphs: 100%|██████████| 100/100 [02:03<00:00,  1.23s/it]
# Processing graphs: 100%|██████████| 100/100 [01:42<00:00,  1.03s/it]
# Processing graphs: 100%|██████████| 100/100 [03:54<00:00,  2.34s/it]
# Processing graphs: 100%|██████████| 100/100 [01:53<00:00,  1.14s/it]
# Processing graphs: 100%|██████████| 100/100 [01:48<00:00,  1.09s/it]
# Processing graphs: 100%|██████████| 100/100 [02:03<00:00,  1.23s/it]
# Processing graphs: 100%|██████████| 100/100 [02:27<00:00,  1.47s/it]
# Processing graphs: 100%|██████████| 100/100 [02:06<00:00,  1.26s/it]
# Processing graphs: 100%|██████████| 100/100 [04:45<00:00,  2.86s/it]
# Processing graphs: 100%|██████████| 100/100 [01:42<00:00,  1.03s/it]
# Processing graphs: 100%|██████████| 100/100 [01:50<00:00,  1.10s/it]
# Processing graphs: 100%|██████████| 100/100 [01:31<00:00,  1.09it/s]
# Processing graphs: 100%|██████████| 100/100 [02:49<00:00,  1.70s/it]
# Processing graphs: 100%|██████████| 100/100 [02:39<00:00,  1.60s/it]
# Processing graphs: 100%|██████████| 100/100 [06:15<00:00,  3.76s/it]
# Processing graphs: 100%|██████████| 100/100 [01:52<00:00,  1.13s/it]
# Processing graphs: 100%|██████████| 100/100 [01:47<00:00,  1.08s/it]
# Processing graphs: 100%|██████████| 100/100 [01:38<00:00,  1.01it/s]
# Processing graphs: 100%|██████████| 100/100 [01:58<00:00,  1.19s/it]
# Processing graphs: 100%|██████████| 100/100 [01:48<00:00,  1.08s/it]
# Processing graphs: 100%|██████████| 100/100 [01:39<00:00,  1.01it/s]
# Processing graphs: 100%|██████████| 100/100 [08:58<00:00,  5.38s/it]
# Processing graphs: 100%|██████████| 100/100 [02:07<00:00,  1.27s/it]
# Processing graphs: 100%|██████████| 100/100 [02:05<00:00,  1.26s/it]
# Processing graphs: 100%|██████████| 100/100 [03:05<00:00,  1.86s/it]
# Processing graphs: 100%|██████████| 100/100 [04:52<00:00,  2.92s/it]
# Processing graphs: 100%|██████████| 100/100 [13:53<00:00,  8.34s/it]

# %%
# test controlled-density perturbations
fractions_of_removals_in_randomly_flipped_edges = [0, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 1]
for fraction in fractions_of_removals_in_randomly_flipped_edges:
    for graph_choices_set, graphs in zip(graph_choice_sets, list_of_graph_lists):
        graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['adjacency', 'neg_laplacian'],
            input_choices=input_choices, edge_score_choices=['random'], sample_multiple_edges_uniformly_num_trials=100, sort_by='graph_edit_distance',
            fraction_of_removals_in_randomly_flipped_edges=fraction,
            results_file='controlled_density_edge_flip_results.csv',
            other_pairs_of_quantities_to_plot=[
                # {'y1': 'random', 'y2': 'Wc_spec_dist'},
                {'y1': 'sys_mat_spec_dist', 'y2': 'Wc_spec_dist'},
                {'y1': 'sys_mat_spec_dist', 'y2': 'density'},
                {'y1': 'Wc_spec_dist', 'y2': 'density'}])
# Out:
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.45it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.47it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.51it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.38it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.48it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.54it/s]
# Processing graphs: 100%|██████████| 100/100 [00:21<00:00,  4.57it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.05it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.53it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.19it/s]
# Processing graphs: 100%|██████████| 100/100 [00:21<00:00,  4.64it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.06it/s]
# Processing graphs: 100%|██████████| 100/100 [00:33<00:00,  2.96it/s]
# Processing graphs: 100%|██████████| 100/100 [00:42<00:00,  2.34it/s]
# Processing graphs: 100%|██████████| 100/100 [00:36<00:00,  2.78it/s]
# Processing graphs: 100%|██████████| 100/100 [00:21<00:00,  4.75it/s]
# Processing graphs: 100%|██████████| 100/100 [00:21<00:00,  4.70it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.03it/s]
# Processing graphs: 100%|██████████| 100/100 [00:26<00:00,  3.84it/s]
# Processing graphs: 100%|██████████| 100/100 [00:21<00:00,  4.61it/s]
# Processing graphs: 100%|██████████| 100/100 [00:21<00:00,  4.68it/s]
# Processing graphs: 100%|██████████| 100/100 [00:26<00:00,  3.82it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.35it/s]
# Processing graphs: 100%|██████████| 100/100 [00:25<00:00,  3.99it/s]
# Processing graphs: 100%|██████████| 100/100 [00:34<00:00,  2.90it/s]
# Processing graphs: 100%|██████████| 100/100 [00:43<00:00,  2.30it/s]
# Processing graphs: 100%|██████████| 100/100 [00:35<00:00,  2.80it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.32it/s]
# Processing graphs: 100%|██████████| 100/100 [00:28<00:00,  3.51it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.34it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.17it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.04it/s]
# Processing graphs: 100%|██████████| 100/100 [00:30<00:00,  3.25it/s]
# Processing graphs: 100%|██████████| 100/100 [00:26<00:00,  3.82it/s]
# Processing graphs: 100%|██████████| 100/100 [00:31<00:00,  3.15it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.27it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.12it/s]
# Processing graphs: 100%|██████████| 100/100 [00:25<00:00,  3.97it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.15it/s]
# Processing graphs: 100%|██████████| 100/100 [00:38<00:00,  2.60it/s]
# Processing graphs: 100%|██████████| 100/100 [01:16<00:00,  1.31it/s]
# Processing graphs: 100%|██████████| 100/100 [03:12<00:00,  1.92s/it]
# Processing graphs: 100%|██████████| 100/100 [00:19<00:00,  5.08it/s]
# Processing graphs: 100%|██████████| 100/100 [00:20<00:00,  4.89it/s]
# Processing graphs: 100%|██████████| 100/100 [00:19<00:00,  5.08it/s]
# Processing graphs: 100%|██████████| 100/100 [00:20<00:00,  4.91it/s]
# Processing graphs: 100%|██████████| 100/100 [00:31<00:00,  3.15it/s]
# Processing graphs: 100%|██████████| 100/100 [00:19<00:00,  5.17it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.22it/s]
# Processing graphs: 100%|██████████| 100/100 [00:33<00:00,  3.02it/s]
# Processing graphs: 100%|██████████| 100/100 [00:19<00:00,  5.06it/s]
# Processing graphs: 100%|██████████| 100/100 [00:32<00:00,  3.06it/s]
# Processing graphs: 100%|██████████| 100/100 [00:36<00:00,  2.74it/s]
# Processing graphs: 100%|██████████| 100/100 [00:32<00:00,  3.07it/s]
# Processing graphs: 100%|██████████| 100/100 [00:21<00:00,  4.65it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.25it/s]
# Processing graphs: 100%|██████████| 100/100 [00:21<00:00,  4.70it/s]
# Processing graphs: 100%|██████████| 100/100 [00:26<00:00,  3.80it/s]
# Processing graphs: 100%|██████████| 100/100 [00:53<00:00,  1.88it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.41it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.30it/s]
# Processing graphs: 100%|██████████| 100/100 [00:26<00:00,  3.71it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.38it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.28it/s]
# Processing graphs: 100%|██████████| 100/100 [00:26<00:00,  3.77it/s]
# Processing graphs: 100%|██████████| 100/100 [00:37<00:00,  2.65it/s]
# Processing graphs: 100%|██████████| 100/100 [00:37<00:00,  2.70it/s]
# Processing graphs: 100%|██████████| 100/100 [00:44<00:00,  2.23it/s]
# Processing graphs: 100%|██████████| 100/100 [01:26<00:00,  1.16it/s]
# Processing graphs: 100%|██████████| 100/100 [00:25<00:00,  3.99it/s]
# Processing graphs: 100%|██████████| 100/100 [00:27<00:00,  3.69it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.02it/s]
# Processing graphs: 100%|██████████| 100/100 [00:25<00:00,  3.92it/s]
# Processing graphs: 100%|██████████| 100/100 [00:26<00:00,  3.73it/s]
# Processing graphs: 100%|██████████| 100/100 [00:25<00:00,  3.99it/s]
# Processing graphs: 100%|██████████| 100/100 [00:25<00:00,  3.95it/s]
# Processing graphs: 100%|██████████| 100/100 [00:45<00:00,  2.21it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.05it/s]
# Processing graphs: 100%|██████████| 100/100 [00:39<00:00,  2.52it/s]
# Processing graphs: 100%|██████████| 100/100 [00:45<00:00,  2.22it/s]
# Processing graphs: 100%|██████████| 100/100 [01:55<00:00,  1.16s/it]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.20it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.22it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.02it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.03it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.19it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.03it/s]
# Processing graphs: 100%|██████████| 100/100 [00:24<00:00,  4.11it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.29it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.37it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.37it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.45it/s]
# Processing graphs: 100%|██████████| 100/100 [00:23<00:00,  4.30it/s]
# Processing graphs: 100%|██████████| 100/100 [00:33<00:00,  2.94it/s]
# Processing graphs: 100%|██████████| 100/100 [01:07<00:00,  1.48it/s]
# Processing graphs: 100%|██████████| 100/100 [00:34<00:00,  2.93it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.41it/s]
# Processing graphs: 100%|██████████| 100/100 [00:21<00:00,  4.59it/s]
# Processing graphs: 100%|██████████| 100/100 [00:29<00:00,  3.40it/s]
# Processing graphs: 100%|██████████| 100/100 [00:22<00:00,  4.40it/s]
# Processing graphs: 100%|██████████| 100/100 [00:26<00:00,  3.81it/s]
# Processing graphs: 100%|██████████| 100/100 [04:01<00:00,  2.41s/it]
# Processing graphs: 100%|██████████| 100/100 [00:27<00:00,  3.70it/s]
# Processing graphs: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s]
# Processing graphs: 100%|██████████| 100/100 [00:25<00:00,  3.90it/s
 100%|██████████| 100/100 [00:48<00:00,  2.07it/s]
# Processing graphs: 100%|██████████| 100/100 [01:16<00:00,  1.31it/s]
# Processing graphs: 100%|██████████| 100/100 [52:44<00:00, 31.64s/it]
# Processing graphs: 100%|██████████| 100/100 [00:40<00:00,  2.45it/s]
# Processing graphs: 100%|██████████| 100/100 [00:36<00:00,  2.77it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 5
#       3 for fraction in fractions_of_removals_in_randomly_flipped_edges:
#       4     for graph_choices_set, graphs in zip(graph_choice_sets, list_of_graph_lists):
# ----> 5         graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_set, graphs, matrix_choices=['adjacency', 'neg_laplacian'],
#       6             input_choices=input_choices, edge_score_choices=['random'], sample_multiple_edges_uniformly_num_trials=100, sort_by='graph_edit_distance',
#       7             fraction_of_removals_in_randomly_flipped_edges=fraction,
#       8             results_file='controlled_density_edge_flip_results.csv',
#       9             other_pairs_of_quantities_to_plot=[
#      10                 # {'y1': 'random', 'y2': 'Wc_spec_dist'},
#      11                 {'y1': 'sys_mat_spec_dist', 'y2': 'Wc_spec_dist'},
#      12                 {'y1': 'sys_mat_spec_dist', 'y2': 'density'},
#      13                 {'y1': 'Wc_spec_dist', 'y2': 'density'}])
#
# File c:\Users\usama\OneDrive\Desktop\distinguish-control-graphs\modules\single_graph_edge_expt.py:365, in graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices, graphs, matrix_choices, input_choices, edge_score_choices, gramian_choices, t_horizon, plot_all_ignoring_low_corr, multiple_toggles, debug_dont_plot, plot_these_graph_matrices_spec_dist, skip_toggling_of_edges_that_disconnect_graph, use_this_sys_matrix_spec_dist_for_corr, sort_by, plot_this, third_plot, label_figure_for_paper, label_figure_for_paper_with_graph_info, plot_single_edge_flip_scores, rand_edge_order, fig_output_file_name, results_file, other_pairs_of_quantities_to_plot, t_horizon_setting_for_ETEC, score_order, sample_multiple_edges_uniformly_num_trials, fraction_of_removals_in_randomly_flipped_edges)
#     363         options['graphs'] = [graphs[expt_no][k] for k in range(n_graphs)]
#     364         options['graph_choices'] = [graph_choices[expt_no] for _ in range(n_graphs)]
# --> 365         results.append(graph_edge_toggling_expt(options, multiple_toggles=multiple_toggles, debug_dont_plot=True,
#     366                                                 sort_by=sort_by, results_file=results_file))
#     367 else:
#     368     graph_edge_toggling_expt(options, plot_all_ignoring_low_corr=plot_all_ignoring_low_corr,
#     369                             multiple_toggles=multiple_toggles, debug_dont_plot=debug_dont_plot,
#     370                             sort_by=sort_by)
#
# File c:\Users\usama\OneDrive\Desktop\distinguish-control-graphs\modules\single_graph_edge_expt.py:279, in graph_edge_toggling_expt(options, debug_dont_plot, multiple_toggles, plot_all_ignoring_low_corr, sort_by, results_file)
#     277     label += " (only removed edges)"
#     278 fig.supxlabel(label)
# --> 279 plt.tight_layout()
#     280 if not debug_dont_plot:
#     281     # fig.legend(loc='outside lower center', ncol=2)
#     282     if options.get('fig_output_file_name', None) is not None:
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\pyplot.py:2843, in tight_layout(pad, h_pad, w_pad, rect)
#    2835 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2836 def tight_layout(
#    2837     *,
#    (...)   2841     rect: tuple[float, float, float, float] | None = None,
#    2842 ) -> None:
# -> 2843     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\figure.py:3640, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3638 previous_engine = self.get_layout_engine()
#    3639 self.set_layout_engine(engine)
# -> 3640 engine.execute(self)
#    3641 if previous_engine is not None and not isinstance(
#    3642     previous_engine, (TightLayoutEngine, PlaceHolderLayoutEngine)
#    3643 ):
#    3644     _api.warn_external('The figure layout has changed to tight')
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\layout_engine.py:186, in TightLayoutEngine.execute(self, fig)
#     169 """
#     170 Execute tight_layout.
#     171
#    (...)    183 .pyplot.tight_layout
#     184 """
#     185 info = self._params
# --> 186 renderer = fig._get_renderer()
#     187 with getattr(renderer, "_draw_disabled", nullcontext)():
#     188     kwargs = get_tight_layout_figure(
#     189         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     190         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     191         rect=info['rect'])
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\figure.py:2850, in Figure._get_renderer(self)
#    2848 def _get_renderer(self):
#    2849     if hasattr(self.canvas, 'get_renderer'):
# -> 2850         return self.canvas.get_renderer()
#    2851     else:
#    2852         return _get_renderer(self)
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:392, in FigureCanvasAgg.get_renderer(self)
#     390 reuse_renderer = (self._lastKey == key)
#     391 if not reuse_renderer:
# --> 392     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     393     self._lastKey = key
#     394 return self.renderer
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:69, in RendererAgg.__init__(self, width, height, dpi)
#      67 self.width = width
#      68 self.height = height
# ---> 69 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      70 self._filter_renderers = []
#      72 self._update_methods()
#
# MemoryError: bad allocation
# Error in callback <function _draw_all_if_interactive at 0x000002A19AD3B740> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\pyplot.py:278, in _draw_all_if_interactive()
#     276 def _draw_all_if_interactive() -> None:
#     277     if matplotlib.is_interactive():
# --> 278         draw_all()
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:377, in FigureCanvasAgg.draw(self)
#     375 def draw(self):
#     376     # docstring inherited
# --> 377     self.renderer = self.get_renderer()
#     378     self.renderer.clear()
#     379     # Acquire a lock on the shared font cache.
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:392, in FigureCanvasAgg.get_renderer(self)
#     390 reuse_renderer = (self._lastKey == key)
#     391 if not reuse_renderer:
# --> 392     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     393     self._lastKey = key
#     394 return self.renderer
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:69, in RendererAgg.__init__(self, width, height, dpi)
#      67 self.width = width
#      68 self.height = height
# ---> 69 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      70 self._filter_renderers = []
#      72 self._update_methods()
#
# MemoryError: bad allocation
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backend_bases.py:2149, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2144 layout_engine = self.figure.get_layout_engine()
#    2145 if layout_engine is not None or bbox_inches == "tight":
#    2146     # we need to trigger a draw before printing to make sure
#    2147     # CL works.  "tight" also needs a draw to get the right
#    2148     # locations:
# -> 2149     renderer = _get_renderer(
#    2150         self.figure,
#    2151         functools.partial(
#    2152             print_method, orientation=orientation)
#    2153     )
#    2154     # we do this instead of `self.figure.draw_without_rendering`
#    2155     # so that we can inject the orientation
#    2156     with getattr(renderer, "_draw_disabled", nullcontext)():
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backend_bases.py:1574, in _get_renderer(figure, print_method)
#    1571     print_method = stack.enter_context(
#    1572         figure.canvas._switch_canvas_and_return_print_method(fmt))
#    1573 try:
# -> 1574     print_method(io.BytesIO())
#    1575 except Done as exc:
#    1576     renderer, = exc.args
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:429, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     424 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     425     """
#     426     Draw the canvas, then save it using `.image.imsave` (to which
#     427     *pil_kwargs* and *metadata* are forwarded).
#     428     """
# --> 429     FigureCanvasAgg.draw(self)
#     430     mpl.image.imsave(
#     431         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:377, in FigureCanvasAgg.draw(self)
#     375 def draw(self):
#     376     # docstring inherited
# --> 377     self.renderer = self.get_renderer()
#     378     self.renderer.clear()
#     379     # Acquire a lock on the shared font cache.
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:392, in FigureCanvasAgg.get_renderer(self)
#     390 reuse_renderer = (self._lastKey == key)
#     391 if not reuse_renderer:
# --> 392     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     393     self._lastKey = key
#     394 return self.renderer
#
# File c:\Users\usama\OneDrive\Documents\misc\micromamba\envs\usual\Lib\site-packages\matplotlib\backends\backend_agg.py:69, in RendererAgg.__init__(self, width, height, dpi)
#      67 self.width = width
#      68 self.height = height
# ---> 69 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      70 self._filter_renderers = []
#      72 self._update_methods()
#
# MemoryError: bad allocation
