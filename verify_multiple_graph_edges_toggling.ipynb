# %% [markdown]
# ### Overview
#
# This code explores whether there is a correlation between toggling of multiple edges (effectively, subgraphs) and spectral/controllability properties. The edges are toggled in the order based on a specified score.

# %%
######################### Uninterseting edge score 'Wc_spec_dist' for cumulative flips

# from modules.single_graph_edge_expt import graph_edge_toggling_expt_using_given_graphs_and_scoring_choice
# from modules.graphs import get_graph
# import numpy as np
# # %config InlineBackend.figure_format = 'svg'

# graph_choices_1 = [{'type': 'connected_ER', 'n': 20, 'p': 0.5},
#                  {'type': 'connected_RG', 'n': 20, 'r': 0.25},
#                  {'type':           'BA', 'n': 20, 'm': 5, 'init': {'type': 'complete', 'n': 5}}]
# n_graphs = 100
# graphs_1 = [[get_graph(graph_choice=choice) for _ in range(n_graphs)] for choice in graph_choices_1]
# matrix_choices = ['neg_laplacian']
# # matrix_choices = ['adjacency', 'neg_laplacian', 'normalized_laplacian', 'neg_normalized_laplacian',
# #                   'signless_laplacian', 'neg_signless_laplacian', 'distance_normalized_laplacian', 'neg_distance_normalized_laplacian']
# # input_choices = ['zfs_transf']
# input_choices = ['all_ones', 'identity', 'zfs', 'zfs_transf', 'zfs_new']

# graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_1, graphs_1, matrix_choices, input_choices,
#         edge_score_choices=['Wc_spec_dist'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

# %%
from modules.single_graph_edge_expt import graph_edge_toggling_expt_using_given_graphs_and_scoring_choice
from modules.graphs import get_graph
import numpy as np
# %config InlineBackend.figure_format = 'svg'

graph_choices_1 = [{'type': 'connected_ER', 'n': 20, 'p': 0.3},
                 {'type': 'connected_RG', 'n': 20, 'r': 0.25},
                 {'type':           'BA', 'n': 20, 'm': 3, 'init': {'type': 'complete', 'n': 5}}]
n_graphs = 100
graphs_1 = [[get_graph(graph_choice=choice) for _ in range(n_graphs)] for choice in graph_choices_1]
matrix_choices = ['neg_laplacian']
# matrix_choices = ['adjacency', 'neg_laplacian', 'normalized_laplacian', 'neg_normalized_laplacian',
#                   'signless_laplacian', 'neg_signless_laplacian', 'distance_normalized_laplacian', 'neg_distance_normalized_laplacian']
# input_choices = ['zfs_transf']
input_choices = ['all_ones', 'identity', 'zfs', 'zfs_transf', 'zfs_new']

graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_1, graphs_1, matrix_choices=['adjacency', 'neg_laplacian'],
        input_choices=input_choices,
        edge_score_choices=['random'], plot_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
        sort_by_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
        multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

# # no significant correlation between sys_mat_spec_dist and random edge score
# graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_1, graphs_1, matrix_choices, input_choices,
#         edge_score_choices=['random'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_1, graphs_1, matrix_choices=['neg_laplacian', 'adjacency'], input_choices=['identity'],
        edge_score_choices=['ETEC'], t_horizon=40, multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')#, plot_all_ignoring_low_corr=True)

graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_1, graphs_1, matrix_choices=['neg_laplacian'], input_choices=['identity'],
        edge_score_choices=['ETEC_sys_mat'], t_horizon=40, multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')#, plot_all_ignoring_low_corr=True)
# Out:
# Processing graphs: 100%|██████████| 100/100 [00:35<00:00,  2.79it/s]
# Processing graphs: 100%|██████████| 100/100 [00:33<00:00,  2.95it/s]
# Processing graphs: 100%|██████████| 100/100 [00:33<00:00,  3.01it/s]

# %%
from modules.single_graph_edge_expt import graph_edge_toggling_expt_using_given_graphs_and_scoring_choice
from modules.graphs import get_graph
import numpy as np
# %config InlineBackend.figure_format = 'svg'

graph_choices_2 = [{'type': 'connected_ER', 'n': 20, 'p': 0.5},
                 {'type': 'connected_RG', 'n': 20, 'r': 0.5},
                 {'type':           'BA', 'n': 20, 'm': 5, 'init': {'type': 'complete', 'n': 5}}]
n_graphs = 100
graphs_2 = [[get_graph(graph_choice=choice) for _ in range(n_graphs)] for choice in graph_choices_2]
matrix_choices = ['neg_laplacian']
input_choices = ['all_ones', 'identity', 'zfs', 'zfs_transf', 'zfs_new']

# system matrix and gramian spectral distance with random ordering of edge flips
graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_2, graphs_2, matrix_choices=['adjacency', 'neg_laplacian'], input_choices=input_choices,
        edge_score_choices=['random'], plot_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
        sort_by_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
        multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_2, graphs_2, matrix_choices=['neg_laplacian', 'adjacency'], input_choices=['identity'],
        edge_score_choices=['ETEC'], t_horizon=40, multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')#, plot_all_ignoring_low_corr=True)

graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_2, graphs_2, matrix_choices=['neg_laplacian'], input_choices=['identity'],
        edge_score_choices=['ETEC_sys_mat'], t_horizon=40, multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')#, plot_all_ignoring_low_corr=True)
# Out:
# Processing graphs: 100%|██████████| 100/100 [00:38<00:00,  2.57it/s]
# Processing graphs: 100%|██████████| 100/100 [00:41<00:00,  2.40it/s]
# Processing graphs: 100%|██████████| 100/100 [00:37<00:00,  2.69it/s]

# %%
from modules.single_graph_edge_expt import graph_edge_toggling_expt_using_given_graphs_and_scoring_choice
from modules.graphs import get_graph
import numpy as np
# %config InlineBackend.figure_format = 'svg'

graph_choices_3 = [{'type': 'connected_ER', 'n': 20, 'p': 0.7},
                 {'type': 'connected_RG', 'n': 20, 'r': 0.75},
                 {'type':           'BA', 'n': 20, 'm': 8, 'init': {'type': 'complete', 'n': 8}}]
n_graphs = 100
graphs_3 = [[get_graph(graph_choice=choice) for _ in range(n_graphs)] for choice in graph_choices_3]
matrix_choices = ['neg_laplacian']
input_choices = ['all_ones', 'identity', 'zfs', 'zfs_transf', 'zfs_new']

# system matrix and gramian spectral distance with random ordering of edge flips
graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_3, graphs_3, matrix_choices=['adjacency', 'neg_laplacian'], input_choices=input_choices,
        edge_score_choices=['random'], plot_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
        sort_by_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
        multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')

graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_3, graphs_3, matrix_choices=['neg_laplacian', 'adjacency'], input_choices=['identity'],
        edge_score_choices=['ETEC'], t_horizon=40, multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')#, plot_all_ignoring_low_corr=True)

graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices_3, graphs_3, matrix_choices=['neg_laplacian'], input_choices=['identity'],
        edge_score_choices=['ETEC_sys_mat'], t_horizon=40, multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')#, plot_all_ignoring_low_corr=True)
# Out:
# Processing graphs: 100%|██████████| 100/100 [00:56<00:00,  1.78it/s]
# Processing graphs: 100%|██████████| 100/100 [00:46<00:00,  2.16it/s]
# Processing graphs: 100%|██████████| 100/100 [00:42<00:00,  2.37it/s]
