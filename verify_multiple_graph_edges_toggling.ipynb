# %% [markdown]
# ### Overview
#
# This code explores whether there is a correlation between toggling of multiple edges (effectively, subgraphs) and spectral/controllability properties. The edges are toggled in the order based on a specified score.

# %%
from modules.single_graph_edge_expt import graph_edge_toggling_expt_using_given_graphs_and_scoring_choice
from modules.graphs import get_graph
import numpy as np
# %config InlineBackend.figure_format = 'svg'

graph_choices = [{'type': 'connected_ER', 'n': 20, 'p': 0.5},
                 {'type': 'connected_RG', 'n': 20, 'r': 0.25},
                 {'type':           'BA', 'n': 20, 'm': 5, 'init': {'type': 'complete', 'n': 5}}]
n_graphs = 10
graphs = [[get_graph(graph_choice=choice) for _ in range(n_graphs)] for choice in graph_choices]
matrix_choices = ['neg_laplacian']
# matrix_choices = ['adjacency', 'neg_laplacian', 'normalized_laplacian', 'neg_normalized_laplacian',
#                   'signless_laplacian', 'neg_signless_laplacian', 'distance_normalized_laplacian', 'neg_distance_normalized_laplacian']
# input_choices = ['zfs_transf']
input_choices = ['all_ones', 'identity', 'zfs', 'zfs_transf', 'zfs_new']

G = graphs[0][0]
rand_edge_order = {(u, v): np.random.rand() for u in G.nodes() for v in G.nodes() if u != v}

# %%
graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices, graphs, matrix_choices, input_choices,
        edge_score_choices=['Wc_spec_dist'], multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')
# Out:
# Processing graphs: 100%|██████████| 100/100 [02:59<00:00,  1.79s/it]
# Processing graphs: 100%|██████████| 100/100 [04:24<00:00,  2.64s/it]
# Skipping plot since correlation coefficients are ['0.49, ', '0.5, '].
# Processing graphs: 100%|██████████| 100/100 [01:01<00:00,  1.61it/s]
# Processing graphs: 100%|██████████| 100/100 [00:51<00:00,  1.93it/s]
# Skipping plot since correlation coefficients are ['-0.14, ', '-0.071, '].
# Processing graphs: 100%|██████████| 100/100 [00:47<00:00,  2.10it/s]
# Skipping plot since correlation coefficients are ['0.5, ', '0.45, '].
# Processing graphs: 100%|██████████| 100/100 [00:53<00:00,  1.89it/s]
# Skipping plot since correlation coefficients are ['0.5, ', '0.35, '].
# Processing graphs: 100%|██████████| 100/100 [00:54<00:00,  1.85it/s]
# Skipping plot since correlation coefficients are ['0.49, ', '0.41, '].
# Processing graphs: 100%|██████████| 100/100 [00:50<00:00,  1.96it/s]
# Skipping plot since correlation coefficients are ['0.49, ', '0.49, '].
# Processing graphs: 100%|██████████| 100/100 [00:57<00:00,  1.75it/s]
# Skipping plot since correlation coefficients are ['0.39, ', '0.32, '].
# Processing graphs: 100%|██████████| 100/100 [01:35<00:00,  1.05it/s]
# Skipping plot since correlation coefficients are ['-0.14, ', '-0.071, '].
# Processing graphs: 100%|██████████| 100/100 [01:51<00:00,  1.11s/it]
# Skipping plot since correlation coefficients are ['0.5, ', '0.45, '].
# Processing graphs: 100%|██████████| 100/100 [02:09<00:00,  1.30s/it]
# Skipping plot since correlation coefficients are ['0.5, ', '0.35, '].

# %%
graph_edge_toggling_expt_using_given_graphs_and_scoring_choice(graph_choices, graphs, matrix_choices, input_choices,
        edge_score_choices=['random'], plot_this_quantity_instead_of_rand_edge_score='Wc_spec_dist',
        sort_by_this_quantity_instead_of_rand_edge_score='Wc_spec_dist', rand_edge_order=rand_edge_order,
        multiple_toggles=True, results_file='cumulative_edge_flip_results.csv')
# Out:
# Processing graphs: 100%|██████████| 100/100 [01:29<00:00,  1.11it/s]
# Processing graphs: 100%|██████████| 100/100 [00:48<00:00,  2.06it/s]
# Processing graphs: 100%|██████████| 100/100 [00:50<00:00,  1.97it/s]
# Processing graphs: 100%|██████████| 100/100 [00:52<00:00,  1.92it/s]
# Processing graphs: 100%|██████████| 100/100 [00:48<00:00,  2.05it/s]
# Processing graphs: 100%|██████████| 100/100 [00:51<00:00,  1.96it/s]
# Processing graphs: 100%|██████████| 100/100 [00:52<00:00,  1.89it/s]
# Processing graphs: 100%|██████████| 100/100 [00:47<00:00,  2.10it/s]
# Processing graphs: 100%|██████████| 100/100 [00:51<00:00,  1.93it/s]
# Processing graphs: 100%|██████████| 100/100 [01:34<00:00,  1.06it/s]
# Processing graphs: 100%|██████████| 100/100 [01:50<00:00,  1.11s/it]
# Processing graphs: 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
